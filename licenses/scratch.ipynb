# %%
import pandas as pd

# %%
all = pd.read_csv('Active_Business_Licenses_in_Providence.csv')[['DBA', 'PRIMARY_LICENSE', 'ADDRESS', 'ZipCode', 'NOTES']]

# %%
parking = all[all['PRIMARY_LICENSE'] == "Parking"]

# %%
parking
# Out:
#                                        DBA PRIMARY_LICENSE  \
# 69                          GATEWAY GARAGE         Parking
# 74                                     LMR         Parking
# 75                       Down City Parking         Parking
# 94                                HOT CLUB         Parking
# 102                    Civic Center Garage         Parking
# 103                            365 Parking         Parking
# 118                     Parking Cosultants         Parking
# 123                         Friendship Lot         Parking
# 154                          Park Row East         Parking
# 174                               Fairview         Parking
# 189                       DOWNCITY PARKING         Parking
# 270                            GIL PARKING         Parking
# 314                        P-3 Parking Lot         Parking
# 320                      Down City Parking         Parking
# 351                            365 Parking         Parking
# ...

# %%
parking.loc[1042, "ZipCode"]
# Out:
# '50 Spaces\nRenewal\nhkilkenny - 10/17/2018 11:34:25 AM'
