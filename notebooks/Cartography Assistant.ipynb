# %%
import osmnx as ox
ox.config(log_console=True, use_cache=False)
ox.__version__
# Out:
# '0.15.1'

# %%
graph = ox.graph_from_place("Providence, RI, USA")

# %%
projected = ox.project_graph(graph)

# %%
ox.plot_graph(projected)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc64b78f990>)

# %%
ox.save_graph_shapefile(projected, filepath='../cartography/data/shapefiles/streets_providence', encoding='utf-8')
