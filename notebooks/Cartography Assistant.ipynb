# %%
import osmnx as ox
ox.config(log_console=True, use_cache=False)
ox.__version__
# Out:
# '0.11'

# %%
graph = ox.graph_from_place("Providence, RI, USA")

# %%
projected = ox.project_graph(graph)

# %%
ox.plot_graph(projected)
# Out:
# (<Figure size 351.9x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x128636cd0>)

# %%
ox.save_graph_shapefile(projected, filename="streets_providence", folder='../cartography/shapefiles/', encoding='utf-8')
